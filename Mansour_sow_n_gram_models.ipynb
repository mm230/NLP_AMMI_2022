# %% [markdown]
# <a href="https://colab.research.google.com/github/mm230/NLP_Lab_Week1/blob/main/Mansour_sow_n_gram_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 style="font-family:verdana;font-size:300%;text-align:center;background-color:#f2f2f2;color:#0d0d0d">AMMI NLP - Review sessions</h1>
#
# <h1 style="font-family:verdana;font-size:180%;text-align:Center;color:#993333"> Lab 3: n-gram models </h1>

# %% [markdown]
# **Big thanks to Amr Khalifa who improved this lab and made it to a Jupyter Notebook!**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %ls
# Out:
# drive/  sample_data/

# %%
# %cd drive/MyDrive/NLP_Week_1_Labs_2022/session3/
# Out:
# /content/drive/MyDrive/NLP_Week_1_Labs_2022/session3

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/NLP_Week_1_Labs_2022/session3'

# %%
import io, sys, math, re
from collections import defaultdict
import numpy as np

# %%
# data_loader
def load_data(filename):
    '''
    parameters:
    filename (string): datafile
    
    Returns:
    data (list of lists): each list is a sentence of the text 
    vocab (dictionary): {word: no of times it appears in the text}
    '''
    fin = io.open(filename, 'r', encoding='utf-8')
    data = []
    vocab = defaultdict(lambda:0)
    for line in fin:
        sentence = line.split()
        data.append(sentence)
        for word in sentence:
            vocab[word] += 1
    return data, vocab

# %%
print("load training set..")
print("\n")
train_data, vocab = load_data("train1.txt")
print(train_data[0])
print("\n")
print("how :",vocab['how'])
print("load validation set")
valid_data, _ = load_data("valid1.txt")
# Out:
# load training set..
#
#
# ['<s>', 'my', 'fathers', "don't", 'speak', 'dutch.', '</s>']
#
#
# how : 107
# load validation set

# %%
def remove_rare_words(data, vocab, mincount = 1):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text 
    vocab (dictionary): {word: number of times it appears in the text}
    mincount(int): the minimum count 
    
    Returns: 
    data_with_unk(list of lists): data after replacing rare words with <unk> token
    '''
    # replace words in data that are not in the vocab 
    # or have a count that is below mincount
    data_with_unk = []

    ## FILL CODE  
    
    for word in data:
      temp = [] 
      for w in word:
        if w not in vocab.keys() or vocab[w] == mincount:
          temp.append("<unk>")
        else:
          temp.append(w)
      data_with_unk.append(temp)
      
    return data_with_unk

# %%
print("remove rare words")
train_data = remove_rare_words(train_data, vocab, mincount = 1)
valid_data = remove_rare_words(valid_data, vocab, mincount = 1)
#train_data
print(train_data[0])
# Out:
# remove rare words
# ['<s>', 'my', '<unk>', "don't", 'speak', '<unk>', '</s>']

# %%
def build_ngram(data, n):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text 
    n (int): size of the n-gram
    
    Returns:
    prob (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    '''
    total_number_words = 0
    counts = defaultdict(lambda: defaultdict(lambda: 0.0))
    # print(counts)

    for sentence in data:
        sentence = tuple(sentence)
        ## FILL CODE
        # dict can be indexed by tuples
        # store in the same dict all the ngrams
        # by using the context as a key and the word as a value
        for i in range(len(sentence)):
            total_number_words +=1
            for k in range(n):
                if i-k < 0:
                    break
                counts[sentence[i-k:i]][sentence[i]] +=1 


    prob = defaultdict(lambda: defaultdict(lambda: 0.0))
    # Build the probabilities from the counts
    # Be careful with how you normalize!

    ## FILL CODE
    for context in counts.keys():
    ## FILL CODE
        denom =0
        for w in counts[context].keys():
            denom += counts[context][w]
        for w in counts[context].keys():
            prob[context][w] = counts[context][w]/denom
    return prob

# %%
          # dict_word = {}
          # if word in dict_word.keys():
          #   dict_word[word] += 1
          # else:
          #   dict_word[word] = 1
          
          # if context in counts.keys():
          #   counts[context] += 1
          # else:
          #   counts[context] = 1
        # return dict_word

# %%
from nltk.corpus import reuters
from nltk import bigrams, trigrams
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance  
for sentence in train_data:
    for w1, w2, w3 in trigrams(sentence, pad_right=True, pad_left=True):
        model[(w1, w2)][w3] += 1
 
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count
        print(model)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# defaultdict(<function <lambda> at 0x7fdc24c3b4d0>, {(None, None): defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fdc24c3b290>, {'<s>': 1.0}), (None, '<s>'): defaultdict(<function <lambda>.<locals>.<lambda> at 0x7fdc24c3b710>, {'my': 0.013127135407300846, 'tomorrow': 0.0003596475454055026, 'he': 0.035425283222442004, 'tom': 0.2064376910627585, 'john': 0.000539471318108254, 'some': 0.0017982377270275131, 'when': 0.007552598453515555, "don't": 0.006114008271893544, 'that': 0.004315770544866032, 'sami': 0.03272792663190074, 'this': 0.010070131271354072, 'to': 0.002337709045135767, 'what': 0.011868368998381586, 'you': 0.014206078043517353, 'i': 0.1251573458011149, 'the': 0.058802373673799674, '<unk>': 0.03416651681352275, 'they': 0.051789246538392376, 'we': 0.01906131990649164, 'a': 0.005394713181082539, 'burn': 0.0003596475454055026, 'would': 0.0016184139543247618, 'in': 0.006653479590001799, 'being': 0.0001798237727027513, 'is': 0.00827189354432656, 'due': 0.000539471318108254, "i've": 0.0032368279086495235, 'where': 31, 'if': 54, 'there': 45, "they're": 16, "i'll": 33, "that's": 18, "what's": 20, 'now': 7, 'neither': 15, 'has': 3, 'she': 84, 'oh,': 3, 'her': 10, 'was': 6, 'do': 55, 'mary': 66, 'philosophy': 1, "we're": 24, 'one': 10, 'those': 6, 'beauty': 1, '"what\'s': 2, 'your': 11, 'why': 32, 'even': 12, 'tomorrow,': 3, "it's": 40, 'many': 6, 'are': 33, 'age': 1, 'body': 1, 'lady': 1, 'as': 18, 'all': 22, 'thomas': 1, "i'm": 85, 'most': 5, 'please': 35, 'stick': 1, 'japan,': 1, 'who': 23, 'for': 11, 'der': 2, 'it': 74, 'dan': 4, 'did': 27, 'call': 2, "wouldn't": 3, 'bill': 2, 'compared': 1, 'lead': 1, 'open': 2, 'layla': 22, 'well,': 4, '"we': 2, 'gaslighting': 2, "they'll": 4, 'have': 9, 'other': 1, 'limit': 1, "tom's": 18, 'try': 2, 'books': 1, 'though': 2, 'how': 48, "layla's": 3, 'while': 4, "sami's": 14, 'bees': 1, 'can': 20, 'tell': 4, 'but': 4, 'without': 1, "we'll": 5, 'could': 9, 'does': 10, 'were': 3, "you'll": 4, 'make': 1, 'his': 20, 'russian': 2, 'das': 1, "let's": 20, 'du': 1, 'pressure': 1, 'hurry': 2, 'both': 12, 'focus': 1, 'maybe': 8, 'show': 1, 'rock': 1, "he's": 12, 'after': 9, 'here': 4, 'birds': 2, "we've": 8, 'looking': 1, 'thank': 2, 'hold': 2, 'by': 5, 'at': 11, 'then': 2, 'around': 1, 'either': 4, "you'd": 2, 'perhaps': 2, 'making': 1, "you're": 23, "i'd": 17, 'preparations': 1, 'man': 3, 'because': 5, 'oil': 1, 'green': 2, 'go': 3, 'two': 4, 'unfortunately,': 4, 'right': 2, '"what': 2, 'since': 2, 'actually,': 2, "where's": 4, 'between': 1, 'only': 2, 'sorry': 1, 'these': 4, 'everybody': 5, 'behold,': 1, "there's": 15, 'from': 4, 'get': 3, 'take': 3, 'reden': 1, 'everyone': 8, 'nearly': 1, 'peter': 3, 'somebody': 1, 'tom,': 1, 'anne': 1, "weren't": 1, 'think': 1, 'put': 6, 'religious': 1, 'hire': 1, 'teach': 1, "parents'": 1, 'english': 2, 'so': 2, 'hang': 2, 'although': 5, "you've": 4, 'art': 1, 'should': 1, 'another': 1, 'look,': 2, 'first': 2, 'so,': 1, 'towards': 1, '"i': 2, 'instead': 1, 'space': 1, 'die': 3, 'sometimes': 2, 'il': 2, 'give': 5, 'jane': 3, 'unlike': 1, 'monday': 1, 'russia': 1, 'boxing': 1, 'which': 6, 'apparently': 1, 'boston': 1, 'eine': 1, 'people': 11, 'sorry,': 2, 'everything': 6, 'just': 5, '"is': 2, 'with': 2, 'linda': 1, 'imagine': 2, '"why': 3, 'germany': 1, 'come': 2, 'friday': 1, 'no': 11, 'during': 3, 'each': 2, 'christmas': 1, 'let': 7, 'glancing': 1, 'police': 2, 'rio': 1, 'life': 2, 'several': 4, 'of': 1, 'fadil': 6, 'taking': 1, 'good': 2, 'wild': 1, 'last': 4, "she's": 5, "what'll": 2, 'however,': 2, 'grab': 1, 'use': 1, 'excuse': 1, 'may': 2, 'je': 1, 'bob': 2, 'astronomers': 1, 'stand': 2, 'kill': 1, 'leave': 2, 'moreover,': 1, '"it\'s': 2, 'doing': 1, 'catch': 1, 'free': 2, '"but': 2, 'behind': 1, 'american': 1, 'lenin': 1, "here's": 2, 'their': 2, 'bring': 2, 'music': 1, 'on': 4, 'first,': 2, 'today': 2, 'almost': 2, 'scientists': 2, 'figured': 1, "they've": 4, 'keep': 5, 'stay': 2, '"they': 1, 'whoever': 2, 'japan': 2, "can't": 2, 'soon': 1, 'before ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-69bb628d0aef> in <module>()
#      16     for w3 in model[w1_w2]:
#      17         model[w1_w2][w3] /= total_count
# ---> 18         print(model)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     545                 )
#     546             data.group = group
# --> 547         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     548
#     549     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# RUN TO BUILD NGRAM MODEL

n = 2
print("build ngram model with n = ", n)
model = build_ngram(train_data, n)
# Out:
# build ngram model with n =  2

# %%
model
# Out:
# defaultdict(<function __main__.build_ngram.<locals>.<lambda>>,
#             {(): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<s>': 0.08427417521633049,
#                           'my': 0.00307636352614909,
#                           '<unk>': 0.08683528573809993,
#                           "don't": 0.003015745525633837,
#                           'speak': 0.000181854001545759,
#                           '</s>': 0.08427417521633049,
#                           'tomorrow': 6.0618000515253e-05,
#                           'is': 0.01113855759467774,
#                           'the': 0.07075636110142906,
#                           'election.': 4.546350038643975e-05,
#                           'he': 0.006516435055389698,
#                           'worked': 7.577250064406626e-05,
#                           'hard': 0.000242472002061012,
#                           'to': 0.026687074726840135,
#                           'make': 0.000666798005667783,
',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('attic.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('son.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('gone',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'a': 0.09090909090909091,
#                           'back': 0.09090909090909091,
#                           'by': 0.18181818181818182,
#                           'on': 0.09090909090909091,
#                           'over': 0.18181818181818182,
#                           'there': 0.09090909090909091,
#                           'to': 0.2727272727272727}),
#              ('six',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'feet': 0.14285714285714285,
#                           'hours': 0.14285714285714285,
#                           'in': 0.14285714285714285,
#                           'members': 0.14285714285714285,
#                           'months.': 0.14285714285714285,
#                           'times': 0.14285714285714285,
#                           'years': 0.14285714285714285}),
#              ('afternoon.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('over',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'50': 0.023809523809523808,
#                           '<unk>': 0.07142857142857142,
#                           'a': 0.023809523809523808,
#                           'an': 0.023809523809523808,
#                           'and': 0.023809523809523808,
#                           'at': 0.023809523809523808,
#                           'for': 0.023809523809523808,
#                           'his': 0.047619047619047616,
#                           'me': 0.023809523809523808,
#                           'the': 0.30952380952380953,
#                           'them,': 0.023809523809523808,
#                           'there': 0.07142857142857142,
#                           'there,': 0.023809523809523808,
#                           'there.': 0.047619047619047616,
#                           'there?': 0.16666666666666666,
#                           'this': 0.023809523809523808,
#                           'time.': 0.023809523809523808,
#                           'to': 0.023809523809523808}),
#              ('quite',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.2222222222222222,
#                           'beyond': 0.1111111111111111,
#                           'busy': 0.1111111111111111,
#                           'different.': 0.1111111111111111,
#                           'famous': 0.1111111111111111,
#                           'the': 0.1111111111111111,
#                           'tight.': 0.1111111111111111,
#                           'well.': 0.1111111111111111}),
#              ('quiet.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('replace',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'it': 0.3333333333333333,
#                           'the': 0.6666666666666666}),
#              ('question',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'about': 0.1111111111111111,
#                           'and': 0.1111111111111111,
#                           'as': 0.1111111111111111,
#                           'came': 0.1111111111111111,
#                           'the': 0.1111111111111111,
#                           'them.': 0.1111111111111111,
#                           'throughout': 0.1111111111111111,
#                           'whether': 0.1111111111111111,
#                           'which': 0.1111111111111111}),
#              ('reason',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'for': 0.08333333333333333,
#                           'i': 0.08333333333333333,
#                           "i'm": 0.08333333333333333,
#                           'mary': 0.08333333333333333,
#                           'that': 0.08333333333333333,
#                           'to': 0.08333333333333333,
#                           'tom': 0.16666666666666666,
#                           'why': 0.25,
#                           "you're": 0.08333333333333333}),
#              ('existence',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'of': 1.0}),
#              ('universe.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('possibly',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'do': 0.3333333333333333,
#                           'for': 0.3333333333333333,
#                           'take': 0.3333333333333333}),
#              ('young',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.09523809523809523,
#                           'and': 0.14285714285714285,
#                           'children': 0.047619047619047616,
#                           'for': 0.047619047619047616,
#                           'generation.': 0.047619047619047616,
#                           'healthy': 0.047619047619047616,
#                           'japanese': 0.047619047619047616,
#                           'man': 0.14285714285714285,
#                           'men': 0.047619047619047616,
#                           'ones': 0.047619047619047616,
#                           'people?': 0.047619047619047616,
#                           'prince': 0.047619047619047616,
#                           'to': 0.09523809523809523,
#                           'woman': 0.047619047619047616,
#                           'woman.': 0.047619047619047616}),
#              ('age.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ("we'll",): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'be': 0.14285714285714285,
#                           'cancel': 0.14285714285714285,
#                           'find': 0.14285714285714285,
#                           'miss': 0.14285714285714285,
#                           'never': 0.2857142857142857,
#                           'take': 0.14285714285714285}),
#              ('afraid.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('officers',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.5, 'arrested': 0.5}),
#              ('arrested',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'all': 0.16666666666666666,
#                           'by': 0.16666666666666666,
#                           'the': 0.3333333333333333,
#                           'three': 0.16666666666666666,
#                           'tom': 0.16666666666666666}),
#              ('three',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.05555555555555555,
#                           'books.': 0.027777777777777776,
#                           'brothers.': 0.027777777777777776,
#                           'children': 0.027777777777777776,
#                           'day': 0.027777777777777776,
#                           'days.': 0.08333333333333333,
#                           'dollars': 0.027777777777777776,
#                           'girls': 0.027777777777777776,
#                           'guys': 0.027777777777777776,
#                           'hours.': 0.05555555555555555,
#                           'hundred': 0.08333333333333333,
#                           'kilometers': 0.05555555555555555,
#                           'mistakes': 0.027777777777777776,
#                           'months.': 0.027777777777777776,
#                           'more': 0.027777777777777776,
#                           'of': 0.05555555555555555,
#                           'or': 0.027777777777777776,
#                           'other': 0.027777777777777776,
#                           'people': 0.027777777777777776,
#                           'ships': 0.027777777777777776,
#                           'things': 0.027777777777777776,
#                           'times': 0.08333333333333333,
#                           'times.': 0.027777777777777776,
#                           'weeks.': 0.08333333333333333}),
#              ('things.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('coming.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('natural',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.5, 'language': 0.5}),
#              ('cook',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'put': 0.3333333333333333,
#                           'than': 0.3333333333333333,
#                           'well.': 0.3333333333333333}),
#              ('committed',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'any': 0.5, 'to': 0.5}),
#              ('decisions',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'based': 0.25, 'i': 0.25, 'in': 0.25, 'made': 0.25}),
#              ('stayed',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'at': 0.2,
#                           'home.': 0.1,
#                           'in': 0.4,
#                           'on': 0.2,
#                           'with': 0.1}),
#              ('second',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.3333333333333333,
#                           'highest': 0.1111111111111111,
#                           'part': 0.1111111111111111,
#                           'time:': 0.1111111111111111,
#                           'world': 0.2222222222222222,
#                           'year': 0.1111111111111111}),
#              ('special',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'<unk>': 0.5, 'interest': 0.5}),
#              ('stuff',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'into': 0.5, 'you': 0.5}),
#              ('garage.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('needs',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'to': 1.0}),
#              ('begin?',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('peacefully',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'in': 0.5, 'last': 0.5}),
#              ('realize',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'that': 0.25, 'the': 0.5, 'what': 0.25}),
#              ('wait.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('point',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'and': 0.125,
#                           'i': 0.125,
#                           "i'd": 0.125,
#                           'of': 0.5,
#                           'that': 0.125}),
#              ('down',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'again.': 0.030303030303030304,
#                           'and': 0.030303030303030304,
#                           'at': 0.030303030303030304,
#                           'behind': 0.030303030303030304,
#                           'by': 0.06060606060606061,
#                           'from': 0.06060606060606061,
#                           'in': 0.06060606060606061,
#                           'on': 0.09090909090909091,
#                           'recently.': 0.030303030303030304,
#                           'than': 0.030303030303030304,
#                           'the': 0.3333333333333333,
#                           'their': 0.06060606060606061,
#                           'there.': 0.06060606060606061,
#                           'through': 0.030303030303030304,
#                           'to': 0.06060606060606061}),
#              ('stairs',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'and': 0.5, 'together.': 0.5}),
#              ('turn',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'down': 0.14285714285714285,
#                           'off': 0.2857142857142857,
#                           'on': 0.21428571428571427,
#                           'right': 0.07142857142857142,
#                           'the': 0.07142857142857142,
#                           'to': 0.07142857142857142,
#                           'up': 0.14285714285714285}),
#              ('music.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ('happy',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'about': 0.16666666666666666,
#                           'after': 0.08333333333333333,
#                           "father's": 0.08333333333333333,
#                           'if': 0.08333333333333333,
#                           'or': 0.08333333333333333,
#                           'the': 0.08333333333333333,
#                           'to': 0.08333333333333333,
#                           'voices': 0.08333333333333333,
#                           'with': 0.25}),
#              ('results.',): defaultdict(<function __main__.build_ngram.<locals>.<lambda>.<locals>.<lambda>>,
#                          {'</s>': 1.0}),
#              ...})

# %% [markdown]
# Here, implement a recursive function over shorter and shorter context to compute a "stupid backoff model". An interpolation model can also be implemented this way.

# %%
def get_prob(model, context, w):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    } 
    context (list of strings): a sentence
    w(string): the word we need to find it's probability given the context
    
    Retunrs:
    prob(float): probability of this word given the context 
    '''

    # code a recursive function over 
    # smaller and smaller context
    # to compute the backoff model
    
    ## FILL CODE
    if context in model and w in model[context]:
        return model[context][w]
    else:
        return 0.4*get_prob(model, context[1:], w)

# %%
def perplexity(model, data, n):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    } 
    data (list of lists): each list is a sentence of the text
    n(int): size of the n-gram
    
    Retunrs:
    perp(float): the perplexity of the model 
    '''
    ## FILL CODE
    perp, T = 0.0, 0
    for sentence in data:
        sentence = tuple(sentence)
        for i in range(1, len(sentence)):
            nc = min(n-1, i)
            context = sentence[i-nc:i]
            perp += -math.log(get_prob(model, context, sentence[i]))
            T += 1
    perp = math.exp(perp/T)
    return perp

# %%
# COMPUTE PERPLEXITY ON VALIDATION SET

print("The perplexity is", perplexity(model, valid_data, n=n))
# Out:
# The perplexity is 53.582886955857006

# %%
def get_proba_distrib(model, context):
    ## need to get the the words after the context and their probability of appearance
    ## after this context 
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    context (list of strings): the sentence we need to find the words after it and 
    thier probabilites
    
    Retunrs:
    words_and_probs(dic): {word: probability of word given context}
    
    '''
    # code a recursive function over context
    # to find the longest available ngram
    
    ## FILL CODE
    if context in model:
        return model[context]
    else:
        return get_proba_distrib(model, context[1:])

# %%
def generate(model):
    '''
    Parameters: 
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    
    Retunrs:
    sentence (list of strings): a sentence sampled according to the language model. 
    

    '''
    # generate a sentence. A sentence starts with a <s> and ends with a </s>
    # Possiblly a use function is:
    # np.random.choice(x, 1, p = y)

    # where x is a list of things to sample from
    # and y is a list of probability (of the same length as x)
    sentence = ["<s>"]
    while sentence[-1] != "</s>" and len(sentence)<100:
        ## FILL CODE
        proba = get_proba_distrib(model, tuple(sentence))
        w = np.random.choice((list(proba.keys())), 1, p = list(proba.values()))
        sentence.append(w[0])
    return sentence

# %%
# GENERATE A SENTENCE FROM THE MODEL

print("Generated sentence: ",generate(model))
# Out:
# Generated sentence:  ['<s>', 'man', 'on', 'the', '<unk>', '</s>']

# %% [markdown]
# Once you are done implementing the model, evaluation and generation code, you can try changing the value of `n`, and play with a larger training set (`train2.txt` and `valid2.txt`). You can also try to implement an interpolation model.
